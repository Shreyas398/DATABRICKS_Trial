# %%
print("Hello World")

# %%
# %sql
SELECT "Hello World FROM SQL!!"
--comment to test git

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# text with a **bold** and *italicized* in it.
#
# Ordered list
# 1. first
# 1. second
# 1. third
#
# Unordered list
# * coffee
# * tea
# * milk
#
#
# Images:
# ![Associate-badge](https://www.databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)
#
# And of course, tables:
#
# | user_id | user_name |
# |---------|-----------|
# |    1    |    Adam   |
# |    2    |    Sarah  |
# |    3    |    John   |
#
# Links (or Embedded HTML): <a href="https://docs.databricks.com/notebooks/notebooks-manage.html" target="_blank"> Managing Notebooks documentation</a>

# %%
# Magic command to run another notebook
# %run /Workspace/Shared/Includes/Setup

# %%
# print(full_name)

# %% [markdown]
# ###  Default dataset location available in every workspace

# %%
# %fs ls '/databricks-datasets'

# %%
# dbtils (DataBricks Utilities) provides a number of utility commands for configuring and interacting with the enviroonments

dbutils.help()

# %%
# dbutils.fs allows you to interact with the databricks filesystem
dbutils.fs.help()

# %%
files = dbutils.fs.ls('/databricks-datasets')
print(files)

# %%
# structured format output
display(files)

# %%
import os
print(os.getcwd())

# %%
print(dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get())

# %%
# Fibonacci series

a = 0
b = 1
while b <= 100:
    print(b)
    temp = a
    a = b
    b = temp + b
